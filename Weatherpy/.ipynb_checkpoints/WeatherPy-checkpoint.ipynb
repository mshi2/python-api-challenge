# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['port elizabeth', 'chuy', 'celestun', 'rikitea', 'cap malheureux', 'jalu', 'hilo', 'kruisfontein', 'illoqqortoormiut', 'new norfolk', 'rio grande', 'cherskiy', 'torbay', 'atuona', 'santa rosa de viterbo', 'airai', 'deputatskiy', 'bambous virieux', 'bethel', 'victoria', 'lakes entrance', 'mar del plata', 'laguna', 'mayumba', 'ancud', 'kodiak', 'chadiza', 'khatanga', 'ushuaia', 'talara', 'brownwood', 'pokrovsk', 'hermanus', 'faanui', 'villa sandino', 'hasaki', 'zhigansk', 'butaritari', 'hobart', 'ilulissat', 'ponta do sol', 'sokolo', 'vaini', 'upernavik', 'albany', 'kalengwa', 'arak', 'maldonado', 'dingle', 'grindavik', 'srednekolymsk', 'fare', 'dikson', 'castro', 'soto la marina', 'newport', 'sungaipenuh', 'nelson bay', 'avarua', 'trincomalee', 'tuktoyaktuk', 'pinega', 'saint-philippe', 'nanortalik', 'vestmanna', 'lompoc', 'lebu', 'belushya guba', 'harper', 'mahebourg', 'mys shmidta', 'nazas', 'amderma', 'busselton', 'rondonopolis', 'grand river south east', 'mataura', 'cape town', 'tasiilaq', 'provideniya', 'port alfred', 'katsiveli', 'little current', 'chokurdakh', 'bluff', 'vostok', 'jamestown', 'thompson', 'katherine', 'cidreira', 'taolanaro', 'qiyang', 'boden', 'nikolskoye', 'yulara', 'cabedelo', 'katsuura', 'nishihara', 'east london', 'kapaa', 'buguruslan', 'puerto ayora', 'turukhansk', 'qaanaaq', 'hualmay', 'tsihombe', 'honiara', 'kavieng', 'college', 'punta arenas', 'barrow', 'portland', 'san cristobal', 'san patricio', 'muros', 'kavaratti', 'caravelas', 'mahadday weyne', 'pouembout', 'poronaysk', 'pisco', 'longyearbyen', 'hithadhoo', 'basudebpur', 'rundu', 'husavik', 'rudnyy', 'morristown', 'leshan', 'clyde river', 'souillac', 'pangai', 'conceicao da barra', 'yellowknife', 'tabiauea', 'nayoro', 'kamenskoye', 'sao joao da barra', 'liuhe', 'ambilobe', 'nsanje', 'craig', 'svetlyy', 'tawkar', 'emerald', 'namatanai', 'wanning', 'kieta', 'palmer', 'vestmannaeyjar', 'buraydah', 'severo-kurilsk', 'tuatapere', 'ukiah', 'kasongo-lunda', 'lapa', 'havelock', 'pa sang', 'bredasdorp', 'paamiut', 'georgetown', 'hunza', 'vasto', 'araouane', 'barentsburg', 'saskylakh', 'roald', 'belyy yar', 'yerkoy', 'keetmanshoop', 'puerto del rosario', 'hofn', 'richards bay', 'komsomolskiy', 'noumea', 'grand-santi', 'matamoros', 'farafenni', 'saint george', 'acajutla', 'luderitz', 'takoradi', 'ahipara', 'nindiri', 'tucuman', 'talnakh', 'aykhal', 'mount gambier', 'bathsheba', 'kefamenanu', 'palizada', 'kondinskoye', 'salalah', 'salima', 'coahuayana', 'meulaboh', 'arraial do cabo', 'alotau', 'amacuzac', 'sinnamary', 'vardo', 'lolua', 'vaitupu', 'bilma', 'waw', 'huarmey', 'shache', 'beloha', 'yatou', 'kaitangata', 'marawi', 'samarai', 'serendah', 'shingu', 'tarauaca', 'elat', 'fortuna', 'nemuro', 'bengkulu', 'norman wells', 'wagar', 'touros', 'abu kamal', 'bokspits', 'qandala', 'lorengau', 'padang', 'boyolangu', 'sao filipe', 'westport', 'stromness', 'poum', 'mayor pablo lagerenza', 'sembe', 'burgeo', 'utiroa', 'kazachinskoye', 'nabire', 'waipawa', 'cayenne', 'neiafu', 'cambyreta', 'cabo san lucas', 'kiruna', 'linjiang', 'naples', 'hami', 'salina cruz', 'okhotsk', 'yemelyanovo', 'sabang', 'san luis', 'sept-iles', 'alice springs', 'milkovo', 'lakselv', 'smithers', 'svirstroy', 'barawe', 'dengfeng', 'mersing', 'marystown', 'snyder', 'bethal', 'naberera', 'saldanha', 'yirol', 'pandamatenga', 'morehead', 'camacha', 'maykain', 'saint-francois', 'kagoro', 'oranjemund', 'hamilton', 'preobrazheniye', 'suntar', 'egvekinot', 'karkaralinsk', 'atbasar', 'tahe', 'zaysan', 'lake in the hills', 'cranbourne', 'aswan', 'pasighat', 'henties bay', 'mega', 'chake chake', 'luwuk', 'tiksi', 'quang ngai', 'chapais', 'vila', 'tortosa', 'dunedin', 'pevek', 'ribeira grande', 'bonthe', 'muborak', 'cumbum', 'kharian', 'winnemucca', 'tumannyy', 'ixtapa', 'shitkino', 'deh rawud', 'sumbe', 'marsa matruh', 'zalaegerszeg', 'pajan', 'akhmim', 'north bend', 'smolenka', 'barbar', 'dalton', 'sioux lookout', 'hurbanovo', 'baboua', 'port augusta', 'pontal do parana', 'luanda', 'klaksvik', ' ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
#Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#lists for holding values
cityname = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
latitude = []
longitude = []
count = 1

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cityname.append(response['name'])
        temperature.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        print(f"Fetching Record {count} | {city}") 
        count += 1
    except:
        print("city not found")
        continue
#print(f"End of requests)
# Out:
# Fetching Record 1 | port elizabeth
# Fetching Record 2 | chuy
# Fetching Record 3 | celestun
# Fetching Record 4 | rikitea
# Fetching Record 5 | cap malheureux
# Fetching Record 6 | jalu
# Fetching Record 7 | hilo
# Fetching Record 8 | kruisfontein
# city not found
# Fetching Record 9 | new norfolk
# Fetching Record 10 | rio grande
# Fetching Record 11 | cherskiy
# Fetching Record 12 | torbay
# Fetching Record 13 | atuona
# Fetching Record 14 | santa rosa de viterbo
# Fetching Record 15 | airai
# Fetching Record 16 | deputatskiy
# Fetching Record 17 | bambous virieux
# Fetching Record 18 | bethel
# Fetching Record 19 | victoria
# Fetching Record 20 | lakes entrance
# Fetching Record 21 | mar del plata
# Fetching Record 22 | laguna
# Fetching Record 23 | mayumba
# Fetching Record 24 | ancud
# Fetching Record 25 | kodiak
# Fetching Record 26 | chadiza
# Fetching Record 27 | khatanga
# Fetching Record 28 | ushuaia
# Fetching Record 29 | talara
# Fetching Record 30 | brownwood
# Fetching Record 31 | pokrovsk
# Fetching Record 32 | hermanus
# Fetching Record 33 | faanui
# Fetching Record 34 | villa sandino
# Fetching Record 35 | hasaki
# Fetching Record 36 | zhigansk
# Fetching Record 37 | butaritari
# Fetching Record 38 | hobart
# Fetching Record 39 | ilulissat
# Fetching Record 40 | ponta do sol
# Fetching Record 41 | sokolo
# Fetching Record 42 | vaini
# Fetching Record 43 | upernavik
# Fetching Record 44 | albany
# Fetching Record 45 | kalengwa
# Fetching Record 46 | arak
# Fetching Record 47 | maldonado
# Fetching Record 48 | dingle
# Fetching Record 49 | grindavik
# Fetching Record 50 | srednekolymsk
# Fetching Record 51 | fare
# Fetching Record 52 | dikson
# Fetching Record 53 | castro
# Fetching Record 54 | soto la marina
# Fetching Record 55 | newport
# Fetching Record 56 | sungaipenuh
# Fetching Record 57 | nelson bay
# Fetching Record 58 | avarua
# Fetching Record 59 | trincomalee
# Fetching Record 60 | tuktoyaktuk
# Fetching Record 61 | pinega
# Fetching Record 62 | saint-philippe
# Fetching Record 63 | nanortalik
# Fetching Record 64 | vestmanna
# Fetching Record 65 | lompoc
# Fetching Record 66 | lebu
# city not found
# Fetching Record 67 | harper
# Fetching Record 68 | mahebourg
# city not found
# Fetching Record 69 | nazas
# city not found
# Fetching Record 70 | busselton
# Fetching Record 71 | rondonopolis
# city not found
# Fetching Record 72 | mataura
# Fetching Record 73 | cape town
# Fetching Record 74 | tasiilaq
# Fetching Record 75 | provideniya
# Fetching Record 76 | port alfred
# city not found
# Fetching Record 77 | little current
# Fetching Record 78 | chokurdakh
# Fetching Record 79 | bluff
# Fetching Record 80 | vostok
# Fetching Record 81 | jamestown
# Fetching Record 82 | thompson
# Fetching Record 83 | katherine
# Fetching Record 84 | cidreira
# city not found
# Fetching Record 85 | qiyang
# Fetching Record 86 | boden
# Fetching Record 87 | nikolskoye
# Fetching Record 88 | yulara
# Fetching Record 89 | cabedelo
# Fetching Record 90 | katsuura
# Fetching Record 91 | nishihara
# Fetching Record 92 | east london
# Fetching Record 93 | kapaa
# Fetching Record 94 | buguruslan
# Fetching Record 95 | puerto ayora
# Fetching Record 96 | turukhansk
# Fetching Record 97 | qaanaaq
# Fetching Record 98 | hualmay
# city not found
# Fetching Record 99 | honiara
# Fetching Record 100 | kavieng
# Fetching Record 101 | college
# Fetching Record 102 | punta arenas
# Fetching Record 103 | barrow
# Fetching Record 104 | portland
# Fetching Record 105 | san cristobal
# Fetching Record 106 | san patricio
# Fetching Record 107 | muros
# Fetching Record 108 | kavaratti
# Fetching Record 109 | caravelas
# city not found
# Fetching Record 110 | pouembout
# Fetching Record 111 | poronaysk
# Fetching Record 112 | pisco
# Fetching Record 113 | longyearbyen
# Fetching Record 114 | hithadhoo
# Fetching Record 115 | basudebpur
# Fetching Record 116 | rundu
# Fetching Record 117 | husavik
# Fetching Record 118 | rudnyy
# Fetching Record 119 | morristown
# Fetching Record 120 | leshan
# Fetching Record 121 | clyde river
# Fetching Record 122 | souillac
# Fetching Record 123 | pangai
# Fetching Record 124 | conceicao da barra
# Fetching Record 125 | yellowknife
# city not found
# Fetching Record 126 | nayoro
# city not found
# Fetching Record 127 | sao joao da barra
# Fetching Record 128 | liuhe
# Fetching Record 129 | ambilobe
# Fetching Record 130 | nsanje
# Fetching Record 131 | craig
# Fetching Record 132 | svetlyy
# city not found
# Fetching Record 133 | emerald
# Fetching Record 134 | namatanai
# Fetching Record 135 | wanning
# Fetching Record 136 | kieta
# Fetching Record 137 | palmer
# Fetching Record 138 | vestmannaeyjar
# Fetching Record 139 | buraydah
# Fetching Record 140 | severo-kurilsk
# Fetching Record 141 | tuatapere
# Fetching Record 142 | ukiah
# Fetching Record 143 | kasongo-lunda
# Fetching Record 144 | lapa
# Fetching Record 145 | havelock
# Fetching Record 146 | pa sang
# Fetching Record 147 | bredasdorp
# Fetching Record 148 | paamiut
# Fetching Record 149 | georgetown
# city not found
# Fetching Record 150 | vasto
# Fetching Record 151 | araouane
# city not found
# Fetching Record 152 | saskylakh
# Fetching Record 153 | roald
# Fetching Record 154 | belyy yar
# Fetching Record 155 | yerkoy
# Fetching Record 156 | keetmanshoop
# Fetching Record 157 | puerto del rosario
# Fetching Record 158 | hofn
# Fetching Record 159 | richards bay
# Fetching Record 160 | komsomolskiy
# Fetching Record 161 | noumea
# Fetching Record 162 | grand-santi
# Fetching Record 163 | matamoros
# Fetching Record 164 | farafenni
# Fetching Record 165 | saint george
# Fetching Record 166 | acajutla
# Fetching Record 167 | luderitz
# Fetching Record 168 | takoradi
# Fetching Record 169 | ahipara
# Fetching Record 170 | nindiri
# Fetching Record 171 | tucuman
# Fetching Record 172 | talnakh
# Fetching Record 173 | aykhal
# Fetching Record 174 | mount gambier
# Fetching Record 175 | bathsheba
# Fetching Record 176 | kefamenanu
# Fetching Record 177 | palizada
# Fetching Record 178 | kondinskoye
# Fetching Record 179 | salalah
# Fetching Record 180 | salima
# Fetching Record 181 | coahuayana
# Fetching Record 182 | meulaboh
# Fetching Record 183 | arraial do cabo
# city not found
# Fetching Record 184 | amacuzac
# Fetching Record 185 | sinnamary
# Fetching Record 186 | vardo
# city not found
# city not found
# Fetching Record 187 | bilma
# Fetching Record 188 | waw
# Fetching Record 189 | huarmey
# Fetching Record 190 | shache
# Fetching Record 191 | beloha
# Fetching Record 192 | yatou
# Fetching Record 193 | kaitangata
# Fetching Record 194 | marawi
# Fetching Record 195 | samarai
# Fetching Record 196 | serendah
# Fetching Record 197 | shingu
# Fetching Record 198 | tarauaca
# Fetching Record 199 | elat
# Fetching Record 200 | fortuna
# Fetching Record 201 | nemuro
# Fetching Record 202 | bengkulu
# Fetching Record 203 | norman wells
# Fetching Record 204 | wagar
# Fetching Record 205 | touros
# Fetching Record 206 | abu kamal
# city not found
# Fetching Record 207 | qandala
# Fetching Record 208 | lorengau
# Fetching Record 209 | padang
# Fetching Record 210 | boyolangu
# Fetching Record 211 | sao filipe
# Fetching Record 212 | westport
# Fetching Record 213 | stromness
# Fetching Record 214 | poum
# Fetching Record 215 | mayor pablo lagerenza
# Fetching Record 216 | sembe
# Fetching Record 217 | burgeo
# city not found
# Fetching Record 218 | kazachinskoye
# Fetching Record 219 | nabire
# Fetching Record 220 | waipawa
# Fetching Record 221 | cayenne
# Fetching Record 222 | neiafu
# city not found
# Fetching Record 223 | cabo san lucas
# Fetching Record 224 | kiruna
# Fetching Record 225 | linjiang
# Fetching Record 226 | naples
# Fetching Record 227 | hami
# Fetching Record 228 | salina cruz
# Fetching Record 229 | okhotsk
# Fetching Record 230 | yemelyanovo
# Fetching Record 231 | sabang
# Fetching Record 232 | san luis
# Fetching Record 233 | sept-iles
# Fetching Record 234 | alice springs
# Fetching Record 235 | milkovo
# Fetching Record 236 | lakselv
# Fetching Record 237 | smithers
# Fetching Record 238 | svirstroy
# city not found
# Fetching Record 239 | dengfeng
# Fetching Record 240 | mersing
# Fetching Record 241 | marystown
# Fetching Record 242 | snyder
# Fetching Record 243 | bethal
# Fetching Record 244 | naberera
# Fetching Record 245 | saldanha
# city not found
# Fetching Record 246 | pandamatenga
# Fetching Record 247 | morehead
# Fetching Record 248 | camacha
# city not found
# Fetching Record 249 | saint-francois
# Fetching Record 250 | kagoro
# Fetching Record 251 | oranjemund
# Fetching Record 252 | hamilton
# Fetching Record 253 | preobrazheniye
# Fetching Record 254 | suntar
# Fetching Record 255 | egvekinot
# city not found
# Fetching Record 256 | atbasar
# Fetching Record 257 | tahe
# Fetching Record 258 | zaysan
# Fetching Record 259 | lake in the hills
# Fetching Record 260 | cranbourne
# Fetching Record 261 | aswan
# Fetching Record 262 | pasighat
# Fetching Record 263 | henties bay
# Fetching Record 264 | mega
# Fetching Record 265 | chake chake
# Fetching Record 266 | luwuk
# Fetching Record 267 | tiksi
# Fetching Record 268 | quang ngai
# Fetching Record 269 | chapais
# Fetching Record 270 | vila
# Fetching Record 271 | tortosa
# Fetching Record 272 | dunedin
# Fetching Record 273 | pevek
# Fetching Record 274 | ribeira grande
# Fetching Record 275 | bonthe
# Fetching Record 276 | muborak
# Fetching Record 277 | cumbum
# Fetching Record 278 | kharian
# Fetching Record 279 | winnemucca
# city not found
# Fetching Record 280 | ixtapa
# Fetching Record 281 | shitkino
# city not found
# Fetching Record 282 | sumbe
# Fetching Record 283 | marsa matruh
# Fetching Record 284 | zalaegerszeg
# Fetching Record 285 | pajan
# Fetching Record 286 | akhmim
# Fetching Record 287 | north bend
# Fetching Record 288 | smolenka
# city not found
# Fetching Record 289 | dalton
# Fetching Record 290 | sioux lookout
# Fetching Record 291 | hurbanovo
# city not found
# Fetching Record 292 | port augusta
# Fetching Record 293 | pontal do parana
# Fetching Record 294 | luanda
# Fetching Record 295 | klaksvik
# Fetching Record 296 | vila velha
# Fetching Record 297 | flinders
# Fetching Record 298 | nuuk
# Fetching Record 299 | itamarandiba
# Fetching Record 300 | pali
# Fetching Record 301 | corpus christi
# Fetching Record 302 | avera
# Fetching Record 303 | kamaishi
# Fetching Record 304 | sangar
# Fetching Record 305 | oro valley
# Fetching Record 306 | dolzhanskaya
# Fetching Record 307 | paramonga
# Fetching Record 308 | haines junction
# Fetching Record 309 | mecca
# Fetching Record 310 | zharkent
# Fetching Record 311 | abu samrah
# Fetching Record 312 | olinda
# Fetching Record 313 | benjamin hill
# Fetching Record 314 | hobyo
# Fetching Record 315 | veshenskaya
# Fetching Record 316 | byron bay
# Fetching Record 317 | esperance
# Fetching Record 318 | te anau
# Fetching Record 319 | trapani
# Fetching Record 320 | coihaique
# Fetching Record 321 | payson
# Fetching Record 322 | aksum
# Fetching Record 323 | fairbanks
# Fetching Record 324 | kurilsk
# Fetching Record 325 | grinnell
# city not found
# Fetching Record 326 | policoro
# city not found
# Fetching Record 327 | west bay
# Fetching Record 328 | karpogory
# Fetching Record 329 | houma
# Fetching Record 330 | zyryanka
# Fetching Record 331 | zhezkazgan
# Fetching Record 332 | khandyga
# Fetching Record 333 | mayo
# Fetching Record 334 | tahta
# Fetching Record 335 | biak
# Fetching Record 336 | pimentel
# city not found
# Fetching Record 337 | narsaq
# Fetching Record 338 | mahajanga
# Fetching Record 339 | khandbari
# Fetching Record 340 | port lincoln
# city not found
# Fetching Record 341 | katobu
# Fetching Record 342 | romanovka
# Fetching Record 343 | qaqortoq
# Fetching Record 344 | cedros
# Fetching Record 345 | geraldton
# city not found
# Fetching Record 346 | soe
# Fetching Record 347 | tallahassee
# Fetching Record 348 | san quintin
# Fetching Record 349 | solok
# Fetching Record 350 | tessalit
# Fetching Record 351 | wiarton
# Fetching Record 352 | carnarvon
# Fetching Record 353 | vitim
# Fetching Record 354 | nipawin
# Fetching Record 355 | kushima
# Fetching Record 356 | pantai remis
# Fetching Record 357 | boa vista
# Fetching Record 358 | pionerskiy
# Fetching Record 359 | vega de alatorre
# Fetching Record 360 | olafsvik
# Fetching Record 361 | codrington
# Fetching Record 362 | ajaccio
# Fetching Record 363 | puerto carreno
# Fetching Record 364 | praia da vitoria
# Fetching Record 365 | jizan
# Fetching Record 366 | constitucion
# Fetching Record 367 | tucuma
# Fetching Record 368 | cockburn town
# Fetching Record 369 | praxedis guerrero
# Fetching Record 370 | tiznit
# Fetching Record 371 | mehamn
# Fetching Record 372 | jinchang
# Fetching Record 373 | terrell
# Fetching Record 374 | agadez
# Fetching Record 375 | tottori
# Fetching Record 376 | langsa
# city not found
# Fetching Record 377 | aksarka
# Fetching Record 378 | kurchum
# Fetching Record 379 | pandan
# Fetching Record 380 | saint-joseph
# Fetching Record 381 | effingham
# Fetching Record 382 | kununurra
# Fetching Record 383 | peleduy
# Fetching Record 384 | mahibadhoo
# Fetching Record 385 | whitehorse
# Fetching Record 386 | aklavik
# Fetching Record 387 | pangnirtung
# Fetching Record 388 | skjervoy
# Fetching Record 389 | fukue
# Fetching Record 390 | broome
# Fetching Record 391 | kumluca
# Fetching Record 392 | mengyin
# Fetching Record 393 | tooele
# Fetching Record 394 | stornoway
# Fetching Record 395 | arroio grande
# city not found
# Fetching Record 396 | oranjestad
# Fetching Record 397 | saint-georges
# Fetching Record 398 | lazaro cardenas
# Fetching Record 399 | korla
# Fetching Record 400 | nome
# Fetching Record 401 | monrovia
# Fetching Record 402 | rawson
# Fetching Record 403 | aguie
# Fetching Record 404 | flin flon
# Fetching Record 405 | larkana
# Fetching Record 406 | linkou
# Fetching Record 407 | aripuana
# Fetching Record 408 | castrovillari
# Fetching Record 409 | durban
# Fetching Record 410 | odweyne
# city not found
# Fetching Record 411 | kutum
# Fetching Record 412 | havre-saint-pierre
# Fetching Record 413 | brae
# Fetching Record 414 | ust-kuyga
# Fetching Record 415 | high level
# city not found
# Fetching Record 416 | palana
# Fetching Record 417 | alofi
# Fetching Record 418 | astana
# Fetching Record 419 | tautira
# Fetching Record 420 | onguday
# Fetching Record 421 | santa rosa
# city not found
# Fetching Record 422 | imbituba
# Fetching Record 423 | acapulco
# Fetching Record 424 | beringovskiy
# Fetching Record 425 | evensk
# Fetching Record 426 | kholodnyy
# Fetching Record 427 | asau
# Fetching Record 428 | begamganj
# Fetching Record 429 | aars
# Fetching Record 430 | saint anthony
# Fetching Record 431 | dandong
# Fetching Record 432 | sahuaripa
# Fetching Record 433 | ca mau
# Fetching Record 434 | novobirilyussy
# city not found
# Fetching Record 435 | benghazi
# Fetching Record 436 | labuhan
# Fetching Record 437 | makakilo city
# Fetching Record 438 | vila franca do campo
# Fetching Record 439 | aguimes
# Fetching Record 440 | port-cartier
# city not found
# Fetching Record 441 | maroantsetra
# Fetching Record 442 | phanom sarakham
# Fetching Record 443 | thessalon
# Fetching Record 444 | cacheu
# Fetching Record 445 | kuito
# Fetching Record 446 | atyashevo
# Fetching Record 447 | batagay
# Fetching Record 448 | bereda
# Fetching Record 449 | gunnedah
# Fetching Record 450 | kwidzyn
# Fetching Record 451 | molokovo
# Fetching Record 452 | terney
# Fetching Record 453 | leningradskiy
# Fetching Record 454 | sitka
# Fetching Record 455 | ust-tsilma
# Fetching Record 456 | shonguy
# Fetching Record 457 | comodoro rivadavia
# Fetching Record 458 | isangel
# Fetching Record 459 | guilin
# Fetching Record 460 | anloga
# Fetching Record 461 | phan thiet
# Fetching Record 462 | tangshan
# Fetching Record 463 | quatre cocos
# Fetching Record 464 | paengaroa
# city not found
# city not found
# Fetching Record 465 | louga
# Fetching Record 466 | guayaramerin
# city not found
# Fetching Record 467 | bilbao
# Fetching Record 468 | karratha
# Fetching Record 469 | lubao
# Fetching Record 470 | shimoda
# Fetching Record 471 | porto novo
# Fetching Record 472 | maniitsoq
# Fetching Record 473 | adrar
# Fetching Record 474 | santana do acarau
# Fetching Record 475 | contamana
# Fetching Record 476 | misratah
# Fetching Record 477 | ostrovnoy
# city not found
# Fetching Record 478 | erzincan
# Fetching Record 479 | genhe
# Fetching Record 480 | hokitika
# Fetching Record 481 | balkhash
# Fetching Record 482 | kaiyuan
# Fetching Record 483 | itarema
# Fetching Record 484 | pokhara
# Fetching Record 485 | mitsamiouli
# city not found
# Fetching Record 486 | buenos aires
# Fetching Record 487 | nesna
# Fetching Record 488 | qinhuangdao
# Fetching Record 489 | sechura
# Fetching Record 490 | nacala
# Fetching Record 491 | farafangana
# Fetching Record 492 | leshukonskoye
# Fetching Record 493 | keti bandar
# city not found
# Fetching Record 494 | ust-ilimsk
# Fetching Record 495 | ondjiva
# Fetching Record 496 | agadir
# Fetching Record 497 | dekernes
# Fetching Record 498 | nalut
# Fetching Record 499 | tynda
# Fetching Record 500 | lavrentiya
# Fetching Record 501 | daru
# Fetching Record 502 | nouadhibou
# Fetching Record 503 | grand gaube
# Fetching Record 504 | dzhebariki-khaya
# city not found
# Fetching Record 505 | la reforma
# city not found
# Fetching Record 506 | thunder bay
# Fetching Record 507 | sai buri
# Fetching Record 508 | banda aceh
# Fetching Record 509 | gazli
# Fetching Record 510 | general roca
# Fetching Record 511 | west wendover
# Fetching Record 512 | deer lake
# Fetching Record 513 | moerai
# Fetching Record 514 | axim
# Fetching Record 515 | hayden
# Fetching Record 516 | moose factory
# Fetching Record 517 | manicore
# Fetching Record 518 | banjar
# Fetching Record 519 | bonfim
# Fetching Record 520 | abha
# Fetching Record 521 | atasu
# Fetching Record 522 | umm kaddadah
# Fetching Record 523 | strezhevoy
# Fetching Record 524 | prince rupert
# Fetching Record 525 | yuci
# Fetching Record 526 | lensk
# city not found
# Fetching Record 527 | rio gallegos
# Fetching Record 528 | pedernales
# Fetching Record 529 | tilichiki
# Fetching Record 530 | yar-sale
# Fetching Record 531 | gatton

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_city = {
    'City': cityname,
    'Temperature': temperature, 
    'Humidity': humidity,
    'Cloudiness': cloudiness,
    'Wind Speed': wind_speed,
    'Lat': latitude, 
    'Lng': longitude 
}
weather_data = pd.DataFrame(weather_city)
weather_data.head()
# Out:
#              City  Temperature  Humidity  Cloudiness  Wind Speed      Lat  \
# 0  Port Elizabeth        66.49        55           0        3.44 -33.9180
# 1            Chui        45.73        77          72        9.10 -33.6971
# 2        Celestún        76.35        89         100        8.52  20.8667
# 3         Rikitea        76.08        85         100       17.81 -23.1203
# 4  Cap Malheureux        78.48        63         100       11.99 -19.9842
#
#         Lng
# 0   25.5701
# 1  -53.4616
# 2  -90.4000
# 3 -134.9692
# 4   57.6142

# %%
#export weather data to csv
weather_data.to_csv("Output/CityWeather.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
#
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_check = weather_data.loc[weather_data['Humidity'] > 100]
humidity_check
# Out:
# Empty DataFrame
# Columns: [City, Temperature, Humidity, Cloudiness, Wind Speed, Lat, Lng]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Temperature']
plt.scatter(x_values,y_values)
plt.title('Latitude vs. Temperature Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for Latitude vs Humidity
x_values = weather_data['Lat']
y_values = weather_data['Humidity']
plt.scatter(x_values,y_values)
plt.title('Latitude vs. Humidity Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a Scatter Plot for Latitude vs Cloudiness
x_values = weather_data['Lat']
y_values = weather_data['Cloudiness']
plt.scatter(x_values,y_values)
plt.title('Latitude vs. Cloudiness Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a Scatter Plot for Latitude vs Wind speed
x_values = weather_data['Lat']
y_values = weather_data['Wind Speed']
plt.scatter(x_values,y_values)
plt.title('Latitude vs. Wind Speed Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
NorthernHemisphere = weather_data.loc[weather_data['Lat'] > 0]
SouthernHemisphere = weather_data.loc[weather_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
NorthernHemisphere
# Out:
#            City  Temperature  Humidity  Cloudiness  Wind Speed      Lat  \
# 2      Celestún        76.35        89         100        8.52  20.8667
# 5          Jalu        80.49        45           0       11.74  29.0331
# 6          Hilo        71.89        90          75        3.44  19.7297
# 10     Cherskiy        48.24        52           0        9.80  68.7500
# 11       Torbay        43.84        86          75       13.80  47.6666
# ..          ...          ...       ...         ...         ...      ...
# 524        Yuci        82.15        44          40       13.42  37.6803
# 525       Lensk        66.72        22         100        7.70  60.7253
# 527  Pedernales        78.80        73          86        3.27  18.0384
# 528   Tilichiki        47.95        75         100        3.85  60.4667
# 529    Yar-Sale        61.18        61         100       15.21  66.8333
#
#           Lng
# 2    -90.4000
# 5     21.5482
# 6   -155.0900
# 10   161.3000
# 11   -52.7314
# ..        ...
# 524  112.7319
# 525  114.9278
# 527  -71.7440
# 528  166.1000
# 529   70.8333
#
# [365 rows x 7 columns]

# %%
# Create a Scatter Plot for temperature vs latitude for northern hemisphere
x_values = NorthernHemisphere['Lat']
y_values = NorthernHemisphere['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,100),fontsize=10,color="red")
plt.title('Northern Hemisphere Latitude vs. Temperature Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5012505122087137

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
SouthernHemisphere
# Out:
#                City  Temperature  Humidity  Cloudiness  Wind Speed      Lat  \
# 0    Port Elizabeth        66.49        55           0        3.44 -33.9180
# 1              Chui        45.73        77          72        9.10 -33.6971
# 3           Rikitea        76.08        85         100       17.81 -23.1203
# 4    Cap Malheureux        78.48        63         100       11.99 -19.9842
# 7      Kruisfontein        69.57        30          55        6.42 -34.0033
# ..              ...          ...       ...         ...         ...      ...
# 512          Moerai        73.83        66          22        8.16 -22.4333
# 516        Manicoré        71.96        91          20        2.08  -5.8092
# 517          Banjar        85.86        68          29        0.54  -8.1900
# 526    Río Gallegos        39.25        87           0        8.05 -51.6226
# 530          Gatton        59.02        64           1        4.16 -27.5500
#
#           Lng
# 0     25.5701
# 1    -53.4616
# 3   -134.9692
# 4     57.6142
# 7     24.7314
# ..        ...
# 512 -151.3333
# 516  -61.3003
# 517  114.9675
# 526  -69.2181
# 530  152.2833
#
# [166 rows x 7 columns]

# %%
# Create a Scatter Plot for temperature vs latitude for southern hemisphere
x_values = SouthernHemisphere['Lat']
y_values = SouthernHemisphere['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 80),fontsize=10,color="red")
plt.title('Southern Hemisphere Latitude vs. Temperature Plot (06/12/21)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5696473369697743

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
